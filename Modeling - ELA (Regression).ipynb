# %% [markdown]
# # Regression - How does a school's environment affect its students' ELA Assessment scores?
#
# Predict percentage of students who will receive 3+ on the ELA assessment

# %% [markdown]
# **Import Packages**

# %%
import pandas as pd
import numpy as np
import pickle

# libraries for cleaning and preprocessing data
from sklearn.preprocessing import StandardScaler

# libraries for modeling
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import RidgeCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# libraries for visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', message='numpy.dtype size changed')

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# **Read Data**

# %%
nyc_schools_ela = pd.read_csv('Data/nyc_schools_ela.csv')
nyc_schools_ela.head()
# Out:
#       DBN                     School Name  Supportive Environment Rating  \
# 0  01M015       P.S. 015 Roberto Clemente                              4
# 1  01M019             P.S. 019 Asher Levy                              3
# 2  01M020            P.S. 020 Anna Silver                              2
# 3  01M034  P.S. 034 Franklin D. Roosevelt                              2
# 4  01M063       The STAR Academy - P.S.63                              3
#
#    Interesting and challenging curriculum  Effective teaching and learning  \
# 0                                       4                                3
# 1                                       4                                4
# 2                                       2                                2
# 3                                       2                                2
# 4                                       4                                3
#
#    Effective school assessment  Clear communication - high expectations  \
# 0                            3                                        3
# 1                            4                                        4
# 2                            2                                        3
# 3                            2                                        3
# 4                            4                                        3
#
#    Teacher collaboration  Safety, inclusivity, social-emotional growth  \
# 0                      3                                             4
# 1                      4                                             4
# 2                      2                                             3
# 3                      3                                             2
# 4                      4                                             4
#
#    Resource allocation and management  ...  \
# 0                                   4  ...
# 1                                   4  ...
# 2                                   3  ...
# 3                                   3  ...
# 4                                   4  ...
#
#    Strong Family-Community Ties Score  Trust Score    Borough  District  \
# 0                                3.80         3.99  Manhattan         1
# 1                                4.10         3.55  Manhattan         1
# 2                                3.64         3.12  Manhattan         1
# 3                                3.33         2.32  Manhattan         1
# 4                                4.01         3.95  Manhattan         1
#
#    Level 1 %  Level 2 %  Level 3 %  Level 4 %  Level 3+ %  % Tested
# 0   7.462687  25.373135  46.268658  20.895523   67.164177  0.387283
# 1  11.956522  32.608696  39.130436  16.304348   55.434784  0.377049
# 2  30.143541  30.143541  28.229666  11.483253   39.712917  0.451404
# 3  33.644859  39.719627  18.224298   8.411215   26.635513  0.668750
# 4   6.250000  35.937500  42.187500  15.625000   57.812500  0.361582
#
# [5 rows x 41 columns]

# %% [markdown]
# **Define features and target**

# %%
X = nyc_schools_ela.drop(['DBN', 'School Name', 'Level 1 %', 'Level 2 %',
                          'Level 3 %', 'Level 4 %', 'Level 3+ %',],
                         axis=1)
y = nyc_schools_ela['Level 3+ %']

# %% [markdown]
# **Encode categorical variables**

# %%
X = pd.get_dummies(X, drop_first=True)

# %% [markdown]
# **Train-test split**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    random_state=220)

# %% [markdown]
# **Standardize variables**

# %%
scale = StandardScaler()
X_train_scale = pd.DataFrame(scale.fit_transform(X_train),
                             columns=X.columns)
X_test_scale = pd.DataFrame(scale.transform(X_test),
                            columns=X.columns)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Multiple Linear Regression
#
# **Scikit-learn Regression**

# %%
linreg = LinearRegression().fit(X_train, y_train)

# %%
print('Train Score:', linreg.score(X_train, y_train))
print('Test Score:', linreg.score(X_test, y_test))
print('Intercept:', linreg.intercept_)
print('Coefficients:', linreg.coef_)
# Out:
# Train Score: 0.8323399819412222
# Test Score: 0.8232247284067848
# Intercept: -123.70777957512888
# Coefficients: [ 1.38792019e+00 -7.89190036e-01 -1.05442339e+00 -7.96426403e-01
#   3.84445794e-01  5.64606942e-01  6.36530951e-01  3.10525808e-02
#   7.88631386e-01 -3.27289163e-01  4.22441859e-01 -4.70842668e+01
#  -2.72672296e+01 -1.14170193e+01  4.73503647e+00  4.70323042e-01
#  -3.52120199e+01  2.46267868e+01 -6.00908258e+00  6.77063217e+00
#   9.22049747e+00  2.13279964e-01  3.96004455e+00  1.00724975e+02
#  -8.61864829e+00  9.77210050e+01 -1.63520161e+00  2.51495823e-01
#   4.57008746e+00 -2.20506321e+00  1.23884469e+00 -2.53872886e-01
#  -6.98372122e+00  4.32971320e+00  8.07880962e-01  2.95705722e+00
#   5.35075639e+00]

# %% [markdown]
# **Statsmodels Linear Regression**

# %%
linreg_ols = sm.OLS(y_train,
                    sm.add_constant(X_train)).fit()

# %%
model_sum = linreg_ols.summary()
print(model_sum)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Level 3+ %   R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.825
# Method:                 Least Squares   F-statistic:                     111.9
# Date:                Tue, 14 Jan 2020   Prob (F-statistic):          1.09e-294
# Time:                        21:40:52   Log-Likelihood:                -3090.1
# No. Observations:                 872   AIC:                             6256.
# Df Residuals:                     834   BIC:                             6437.
# Df Model:                          37
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# const                                            -123.7078     74.841     -1.653      0.099    -270.607      23.191
# Supportive Environment Rating                       1.3879      0.752      1.845      0.065      -0.089       2.865
# Interesting and challenging curriculum             -0.7892      0.844     -0.935      0.350      -2.446       0.868
# Effective teaching and learning                    -1.0544      0.837     -1.259      0.208      -2.698       0.589
# Effective school assessment                        -0.7964      0.814     -0.978      0.328      -2.395       0.802
# Clear communication - high expectations             0.3844      0.817      0.470      0.638      -1.220       1.989
# Teacher collaboration                               0.5646      0.960      0.588      0.557      -1.319       2.449
# Safety, inclusivity, social-emotional growth        0.6365      0.864      0.736      0.462      -1.060       2.333
# Resource allocation and management                  0.0311      1.081      0.029      0.977      -2.090       2.152
# Identifying, tracking, and meeting goals            0.7886      1.034      0.763      0.446      -1.241       2.819
# Thoughtful teacher development and evaluation      -0.3273      1.027     -0.319      0.750      -2.343       1.689
# School decision evaluation and adjustment           0.4224      0.951      0.444      0.657      -1.444       2.289
# Percent English Language Learners                 -47.0843      4.091    -11.510      0.000     -55.114     -39.055
# Percent Students with Disabilities                -27.2672      6.358     -4.288      0.000     -39.748     -14.787
# Percent Self-Contained                            -11.4170      8.737     -1.307      0.192     -28.566       5.732
# Economic Need Index                                 4.7350     13.240      0.358      0.721     -21.253      30.723
# Percent in Temp Housing                             0.4703      5.424      0.087      0.931     -10.175      11.116
# Percent HRA Eligible                              -35.2120     12.686     -2.776      0.006     -60.112     -10.312
# Percent Asian                                      24.6268     13.269      1.856      0.064      -1.419      50.672
# Percent Black                                      -6.0091     13.202     -0.455      0.649     -31.923      19.905
# Percent Hispanic                                    6.7706     13.038      0.519      0.604     -18.821      32.363
# Percent White                                       9.2205     13.033      0.707      0.479     -16.361      34.802
# Principal experience at this school                 0.2133      0.061      3.517      0.000       0.094       0.332
# Percent of teachers with 3+ years of experience     3.9600      2.431      1.629      0.104      -0.812       8.732
# Student Attendance Rate                           100.7250     69.598      1.447      0.148     -35.882     237.332
# Percent of Students Chronically Absent             -8.6186     14.532     -0.593      0.553     -37.142      19.905
# Teacher Attendance Rate                            97.7210     31.988      3.055      0.002      34.935     160.507
# Collaborative Teachers Score                       -1.6352      1.406     -1.163      0.245      -4.396       1.125
# Effective School Leadership Score                   0.2515      0.915      0.275      0.783      -1.544       2.047
# Rigorous Instruction Score                          4.5701      1.474      3.100      0.002       1.677       7.463
# Strong Family-Community Ties Score                 -2.2051      0.776     -2.842      0.005      -3.728      -0.682
# Trust Score                                         1.2388      0.807      1.536      0.125      -0.345       2.822
# District                                           -0.2539      0.108     -2.358      0.019      -0.465      -0.043
# % Tested                                           -6.9837      1.584     -4.409      0.000     -10.093      -3.875
# Borough_Brooklyn                                    4.3297      1.501      2.885      0.004       1.384       7.276
# Borough_Manhattan                                   0.8079      1.207      0.669      0.503      -1.561       3.177
# Borough_Queens                                      2.9571      2.259      1.309      0.191      -1.476       7.390
# Borough_Staten Island                               5.3508      3.022      1.771      0.077      -0.581      11.283
# ==============================================================================
# Omnibus:                       63.436   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              149.298
# Skew:                           0.412   Prob(JB):                     3.80e-33
# Kurtosis:                       4.852   Cond. No.                     8.27e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.27e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create a dataframe from our regression results
lin_table = linreg_ols.summary().tables[1]
lin_table = pd.DataFrame(lin_table.data)
lin_table.columns = lin_table.iloc[0]
lin_table.drop(0, inplace=True)
lin_table = lin_table.set_index(lin_table.columns[0])
lin_table = lin_table.astype(float)
lin_table
# Out:
# 0                                                    coef  std err       t  \
#
# const                                           -123.7078   74.841  -1.653
# Supportive Environment Rating                      1.3879    0.752   1.845
# Interesting and challenging curriculum            -0.7892    0.844  -0.935
# Effective teaching and learning                   -1.0544    0.837  -1.259
# Effective school assessment                       -0.7964    0.814  -0.978
# Clear communication - high expectations            0.3844    0.817   0.470
# Teacher collaboration                              0.5646    0.960   0.588
# Safety, inclusivity, social-emotional growth       0.6365    0.864   0.736
# Resource allocation and management                 0.0311    1.081   0.029
# Identifying, tracking, and meeting goals           0.7886    1.034   0.763
# Thoughtful teacher development and evaluation     -0.3273    1.027  -0.319
# School decision evaluation and adjustment          0.4224    0.951   0.444
# Percent English Language Learners                -47.0843    4.091 -11.510
# Percent Students with Disabilities               -27.2672    6.358  -4.288
# Percent Self-Contained                           -11.4170    8.737  -1.307
# Economic Need Index                                4.7350   13.240   0.358
# Percent in Temp Housing                            0.4703    5.424   0.087
# Percent HRA Eligible                             -35.2120   12.686  -2.776
# Percent Asian                                     24.6268   13.269   1.856
# Percent Black                                     -6.0091   13.202  -0.455
# Percent Hispanic                                   6.7706   13.038   0.519
# Percent White                                      9.2205   13.033   0.707
# Principal experience at this school                0.2133    0.061   3.517
# Percent of teachers with 3+ years of experience    3.9600    2.431   1.629
# Student Attendance Rate                          100.7250   69.598   1.447
# Percent of Students Chronically Absent            -8.6186   14.532  -0.593
# Teacher Attendance Rate                           97.7210   31.988   3.055
# Collaborative Teachers Score                      -1.6352    1.406  -1.163
# Effective School Leadership Score                  0.2515    0.915   0.275
# Rigorous Instruction Score                         4.5701    1.474   3.100
# Strong Family-Community Ties Score                -2.2051    0.776  -2.842
# Trust Score                                        1.2388    0.807   1.536
# District                                          -0.2539    0.108  -2.358
# % Tested                                          -6.9837    1.584  -4.409
# Borough_Brooklyn                                   4.3297    1.501   2.885
# Borough_Manhattan                                  0.8079    1.207   0.669
# Borough_Queens                                     2.9571    2.259   1.309
# Borough_Staten Island                              5.3508    3.022   1.771
#
# 0                                                P>|t|   [0.025   0.975]
#
# const                                            0.099 -270.607   23.191
# Supportive Environment Rating                    0.065   -0.089    2.865
# Interesting and challenging curriculum           0.350   -2.446    0.868
# Effective teaching and learning                  0.208   -2.698    0.589
# Effective school assessment                      0.328   -2.395    0.802
# Clear communication - high expectations          0.638   -1.220    1.989
# Teacher collaboration                            0.557   -1.319    2.449
# Safety, inclusivity, social-emotional growth     0.462   -1.060    2.333
# Resource allocation and management               0.977   -2.090    2.152
# Identifying, tracking, and meeting goals         0.446   -1.241    2.819
# Thoughtful teacher development and evaluation    0.750   -2.343    1.689
# School decision evaluation and adjustment        0.657   -1.444    2.289
# Percent English Language Learners                0.000  -55.114  -39.055
# Percent Students with Disabilities               0.000  -39.748  -14.787
# Percent Self-Contained                           0.192  -28.566    5.732
# Economic Need Index                              0.721  -21.253   30.723
# Percent in Temp Housing                          0.931  -10.175   11.116
# Percent HRA Eligible                             0.006  -60.112  -10.312
# Percent Asian                                    0.064   -1.419   50.672
# Percent Black                                    0.649  -31.923   19.905
# Percent Hispanic                                 0.604  -18.821   32.363
# Percent White                                    0.479  -16.361   34.802
# Principal experience at this school              0.000    0.094    0.332
# Percent of teachers with 3+ years of experience  0.104   -0.812    8.732
# Student Attendance Rate                          0.148  -35.882  237.332
# Percent of Students Chronically Absent           0.553  -37.142   19.905
# Teacher Attendance Rate                          0.002   34.935  160.507
# Collaborative Teachers Score                     0.245   -4.396    1.125
# Effective School Leadership Score                0.783   -1.544    2.047
# Rigorous Instruction Score                       0.002    1.677    7.463
# Strong Family-Community Ties Score               0.005   -3.728   -0.682
# Trust Score                                      0.125   -0.345    2.822
# District                                         0.019   -0.465   -0.043
# % Tested                                         0.000  -10.093   -3.875
# Borough_Brooklyn                                 0.004    1.384    7.276
# Borough_Manhattan                                0.503   -1.561    3.177
# Borough_Queens                                   0.191   -1.476    7.390
# Borough_Staten Island                            0.077   -0.581   11.283

# %% [markdown]
# ### Ridge Regression

# %%
lin_l2 = RidgeCV(scoring='r2', cv=5)
lin_l2.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=5, fit_intercept=True,
#         gcv_mode=None, normalize=False, scoring='r2', store_cv_values=False)

# %%
print('Model Score:', lin_l2.score(X_test, y_test))
# Out:
# Model Score: 0.8286470729206997

# %% [markdown]
# ### SVR

# %%
svm_r = SVR(kernel='linear')
svm_r.fit(X_train_scale, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print('Model Score:', svm_r.score(X_test_scale, y_test))
# Out:
# Model Score: 0.8110291062477624

# %% [markdown]
# **Tuning hyperparameters**

# %%
svm_grid = {'C': [0.01, 0.1, 1, 10],
            'kernel': ['linear', 'rbf', 'poly']}

# %%
svm_gs = GridSearchCV(estimator=SVR(),
                      param_grid=svm_grid,
                      scoring='r2',
                      cv=5, verbose=1, n_jobs=-1)

svm_gs.fit(X_train_scale, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    1.3s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='auto_deprecated', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10],
#                          'kernel': ['linear', 'rbf', 'poly']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=1)

# %%
print('Best params:', svm_gs.best_params_)
print('Train score: %.3f' % svm_gs.best_score_)
print('Test score: %.3f' % svm_gs.score(X_test_scale, y_test))
# Out:
# Best params: {'C': 1, 'kernel': 'linear'}
# Train score: 0.815
# Test score: 0.811

# %% [markdown]
# ### Random Forest Regressor

# %%
rf_v = RandomForestRegressor(random_state=220)

rf_v.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=220, verbose=0,
#                       warm_start=False)

# %%
print('Model Score:', rf_v.score(X_test, y_test))
# Out:
# Model Score: 0.8135407493931502

# %% [markdown]
# **Tuning hyperparameters**

# %%
rf_grid = {'n_estimators': [1300, 1500],
          'max_depth': [12, 13, 14],
          'min_samples_split': [2, 3],
          'min_samples_leaf': [1, 2],
          'max_features': ['sqrt']}

# %%
rf_gs = GridSearchCV(estimator=RandomForestRegressor(random_state=220),
                     param_grid=rf_grid,
                     scoring='r2',
                     cv=5, verbose=1, n_jobs=-1)

rf_gs.fit(X_train, y_train)

pickle.dump(rf_gs, open('Models/rf_ela.sav', 'wb'))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:  2.4min finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=220,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'max_depth': [12, 13, 14], 'max_features': ['sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3],
#                          'n_estimators': [1300, 1500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=1)

# %%
rf_gs = pickle.load(open('Models/rf_ela.sav', 'rb'))

print('Best params:', rf_gs.best_params_)
print('Train score: %.3f' % rf_gs.best_score_)
print('Test score: %.3f' % rf_gs.score(X_test, y_test))
# Out:
# Best params: {'max_depth': 14, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1300}
# Train score: 0.803
# Test score: 0.824

# %% [markdown]
# ## Findings

# %%
rf_feat_imp = pd.DataFrame([list(X_train.columns),
                            rf_gs.best_estimator_.feature_importances_]).T
rf_feat_imp.columns = ['Feature', 'Importance']

rf_feat_imp.sort_values('Importance', inplace=True)

# %%
plt.figure(figsize=(10, 8))
n_features = rf_feat_imp.shape[1]
plt.barh(rf_feat_imp['Feature'][-10:],
         rf_feat_imp['Importance'][-10:],
         align='center')
# plt.yticks(np.arange(n_features), rf_feat_imp.values[-10:])
plt.xlabel('Feature importance')
plt.ylabel('Feature')
plt.title(f'Feature importance in predicting ELA Scores')
sns.despine(left=False, bottom=False)
plt.savefig('Images/ELA_feat_imp.png', bbox_inches='tight');

# %%
plt.figure(figsize=(20, 15))
for row, col in enumerate(list(rf_feat_imp['Feature'][-10:].values)):
    plt.subplot(3, 4, row+1)
    sns.scatterplot(nyc_schools_ela['Level 3+ %'],
                    nyc_schools_ela[col])
